# %%
from math import sqrt

#!/usr/bin/env python3
# Name: Toby Grief
# Group Members: Nathan Perez, Theodore Shen, Bharath Karintha, Nate Cruz

'''
Read a DNA string from user input and return a collapsed substring of embedded Ns to: {count}.

Example:
 input: AaNNNNNNGTC
output: AA{6}GTC

Any lower case letters are converted to uppercase
'''

class DNAstring (str):
  def length (self):
    return (len(self))
  def purify(self):
    ''' Return an upcased version of the string, collapsing a single run of Ns.'''
    pureDNA = self.upper()
    countN = pureDNA.count('N')

    if countN > 0:
      t1 = pureDNA.replace('N' * countN, f"{{{countN}}}")

    return t1

def main():
  ''' Get user DNA data and clean it up.'''
  data = input('DNA data?')
  while (data):
    thisDNA = DNAstring (data)
    pureData = thisDNA.purify()
    print (pureData)
    data = input('DNA data?')

main()
# Out:
# AA{6}GTC
# ATTTAAAAGGG{5}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 39
#      36     print (pureData)
#      37     data = input('DNA data?')
# ---> 39 main()
#
# Cell In[7], line 37, in main()
#      35 pureData = thisDNA.purify()
#      36 print (pureData)
# ---> 37 data = input('DNA data?')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#!/usr/bin/env python3
# Name: Toby Grief
# Group Members: Nathan Perez, Theodore Shen, Bharath Karintha, Nate Cruz

'''
Program docstring goes here.
'''

class FastqString (str):
    ''' Class docstring goes here.'''
    def parse(self):
      ''' Method docstring goes here.'''
      fastqInfo = self
      fastq = fastqInfo.replace("@","")
      fastqArray = fastq.split(":")

      return ("Instrument = {}".format(fastqArray[0]) +
             "\nRun ID = {}".format(fastqArray[1]) +
             "\nFlow Cell ID = {}".format(fastqArray[2]) +
             "\nFlow Cell Lane = {}".format(fastqArray[3]) +
             "\nTile Number = {}".format(fastqArray[4]) +
             "\nX-coord = {}".format(fastqArray[5]) +
             "\nY-coord = {}".format(fastqArray[6]))





def main():
    #@EAS139:136:FC706VJ:2:2104:15343:197393
  ''' Function docstring goes here.'''
  data = input('Input fastq file?')
  fastqInfo = FastqString (data)
  print(fastqInfo.parse())

main()
# Out:
# Instrument = EAS139
# Run ID = 136
# Flow Cell ID = FC706VJ
# Flow Cell Lane = 2
# Tile Number = 2104
# X-coord = 15343
# Y-coord = 197393

# %%
#!/usr/bin/env python3
# Name: Toby Grief
# Group Members: Nathan Perez, Theodore Shen, Bharath Karintha, Nate Cruz
import math
class Triad :
    """
    Calculate angles and distances among a triad of points.

    Author: David Bernick
    Date: March 21, 2013
    Points can be supplied in any dimensional space as long as they are consistent.
    Points are supplied as tupels in n-dimensions, and there should be three
    of those to make the triad. Each point is positionally named as p,q,r
    and the corresponding angles are then angleP, angleQ and angleR.
    Distances are given by dPQ(), dPR() and dQR()

    Required Modules: math
    initialized: 3 positional tuples representing Points in n-space
             p1 = Triad( p=(1,0,0), q=(0,0,0), r=(0,1,0) )
    attributes: p,q,r the 3 tuples representing points in N-space
    methods:  angleP(), angleR(), angleQ() angles measured in radians
          dPQ(), dPR(), dQR() distances in the same units of p,q,r

    """

    def __init__(self,p,q,r) :
        """ Construct a Triad.

        Example construction:
            p1 = Triad( p=(1.,0.,0.), q=(0.,0.,0.), r=(0.,0.,0.) ).
        """
        self.p = p
        self.q = q
        self.r = r

# private helper methods
    def d2 (self,a,b) : # calculate squared distance of point a to b
        return float(sum((ia-ib)*(ia-ib)  for  ia,ib in zip (a,b)))

    def dot (self,a,b) : # dotProd of standard vectors a,b
        return float(sum(ia*ib for ia,ib in zip(a,b)))

    def ndot (self,a,b,c) : # dotProd of vec. a,c standardized to b
        return float(sum((ia-ib)*(ic-ib) for ia,ib,ic in zip (a,b,c)))

# calculate lengths(distances) of segments PQ, PR and QR
    def dPQ (self):
        """ Provides the distance between point p and point q """
        return math.sqrt(self.d2(self.p,self.q))

    def dPR (self):
        """ Provides the distance between point p and point r """
        return math.sqrt(self.d2(self.p,self.r))

    def dQR (self):
        """ Provides the distance between point q and point r """
        return math.sqrt(self.d2(self.q,self.r))

    def angleP (self) :
        """ Provides the angle made at point p by segments pq and pr (radians). """
        return math.acos(self.ndot(self.q,self.p,self.r) /
                         math.sqrt(self.d2(self.q,self.p) * self.d2(self.r,self.p)))

    def angleQ (self) :
        """ Provides the angle made at point q by segments qp and qr (radians). """
        return math.acos(self.ndot(self.p,self.q,self.r) /
                         math.sqrt(self.d2(self.p,self.q) * self.d2(self.r,self.q)))

    def angleR (self) :
        """ Provides the angle made at point r by segments rp and rq (radians). """
        return math.acos(self.ndot(self.p,self.r,self.q) /
                         math.sqrt(self.d2(self.p,self.r) * self.d2(self.q,self.r)))


'''----------------------------------------------------------------------------------'''

class dataString(str)  :

    def __init__(self, dataObject):
        self.dataObject = dataObject

    def parse(self) :
        #C = (39.447, 94.657, 11.824) N = (39.292, 95.716, 11.027) Ca = (39.462, 97.101, 11.465)
        self.dataObject = self.dataObject.replace('C', '')
        self.dataObject = self.dataObject.replace(' ', '')
        self.dataObject = self.dataObject.replace('=', '')
        self.dataObject = self.dataObject.replace('N', '')
        self.dataObject = self.dataObject.replace('a', '')
        self.dataObject = self.dataObject.replace(')(', ',')
        self.dataObject = self.dataObject.replace('(', '')
        self.dataObject = self.dataObject.replace(')', '')
        data2 = self.dataObject.split(",")
        for i in range(len(data2)) :
            data2[i] = float(data2[i])
        return data2

'''----------------------------------------------------------------------------------'''
def main():
  ''' Function docstring goes here'''
  data = input("enter your coordinates:")
  dataObject = dataString(data)

  newData = dataObject.parse()

  pointC = [newData[0],newData[1],newData[2]]
  pointN = [newData[3],newData[4],newData[5]]
  pointCa = [newData[6],newData[7],newData[8]]
  p1 = Triad(pointC,pointN,pointCa)
 # print(pointC)
 # print(newData)
  print(p1.dPQ())
  print(p1.dQR())
  print(math.degrees(p1.angleQ()))



  pass

main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 119
#     113   print(math.degrees(p1.angleQ()))
#     117   pass
# --> 119 main()
#
# Cell In[31], line 100, in main()
#      98 def main():
#      99   ''' Function docstring goes here'''
# --> 100   data = input("enter your coordinates:")
#     101   dataObject = dataString(data)
#     103   newData = dataObject.parse()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\ipykernel\kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import re

t = re.findall(r"[,]?[+-]?\d+.?\d*","C = (39.447, 94.657, 11.824) N = (39.292, 95.716, 11.027) Ca = (39.462, 97.101, 11.465)")
print(t)
# Out:
# ['39.447', '94.657', '11.824', '39.292', '95.716', '11.027', '39.462', '97.101', '11.465']

# %%
#!/usr/bin/env python3
# Name: Toby Grief
# Group Members: Nathan Perez, Theodore Shen, Bharath Karintha, Nate Cruz
short_AA = {
            'CYS': 'C', 'ASP': 'D', 'SER': 'S', 'GLN': 'Q', 'LYS': 'K',
            'ILE': 'I', 'PRO': 'P', 'THR': 'T', 'PHE': 'F', 'ASN': 'N',
            'GLY': 'G', 'HIS': 'H', 'LEU': 'L', 'ARG': 'R', 'TRP': 'W',
            'ALA': 'A', 'VAL': 'V', 'GLU': 'E', 'TYR': 'Y', 'MET': 'M'
            }
long_AA = {value:key for key,value in short_AA.items()}

RNA_codon_table = {
# Second Base
# U             C             A             G
#U
'UUU': 'Phe', 'UCU': 'Ser', 'UAU': 'Tyr', 'UGU': 'Cys',
'UUC': 'Phe', 'UCC': 'Ser', 'UAC': 'Tyr', 'UGC': 'Cys',
'UUA': 'Leu', 'UCA': 'Ser', 'UAA': '---', 'UGA': '---',
'UUG': 'Leu', 'UCG': 'Ser', 'UAG': '---', 'UGG': 'Trp',
#C
'CUU': 'Leu', 'CCU': 'Pro', 'CAU': 'His', 'CGU': 'Arg',
'CUC': 'Leu', 'CCC': 'Pro', 'CAC': 'His', 'CGC': 'Arg',
'CUA': 'Leu', 'CCA': 'Pro', 'CAA': 'Gln', 'CGA': 'Arg',
'CUG': 'Leu', 'CCG': 'Pro', 'CAG': 'Gln', 'CGG': 'Arg',
#A
'AUU': 'Ile', 'ACU': 'Thr', 'AAU': 'Asn', 'AGU': 'Ser',
'AUC': 'Ile', 'ACC': 'Thr', 'AAC': 'Asn', 'AGC': 'Ser',
'AUA': 'Ile', 'ACA': 'Thr', 'AAA': 'Lys', 'AGA': 'Arg',
'AUG': 'Met', 'ACG': 'Thr', 'AAG': 'Lys', 'AGG': 'Arg',
#G
'GUU': 'Val', 'GCU': 'Ala', 'GAU': 'Asp', 'GGU': 'Gly',
'GUC': 'Val', 'GCC': 'Ala', 'GAC': 'Asp', 'GGC': 'Gly',
'GUA': 'Val', 'GCA': 'Ala', 'GAA': 'Glu', 'GGA': 'Gly',
'GUG': 'Val', 'GCG': 'Ala', 'GAG': 'Glu', 'GGG': 'Gly'
}
dnaCodonTable = {key.replace('U','T'):value for key, value in RNA_codon_table.items()}

def main():
    '''Function docstring goes here'''
    dnaCode = input("enter your 3 letter DNA code:")
    #dnaCodonTable.keys(dnaCode)

    if(dnaCode in short_AA):
        print(short_AA[dnaCode])
    elif(dnaCode in dnaCodonTable):
        print(dnaCodonTable[dnaCode])
    elif(dnaCode in long_AA):
        print(long_AA[dnaCode])
    elif(dnaCode in RNA_codon_table):
        print(RNA_codon_table[dnaCode])
    else:
        print("unknown")




main()
# Out:
# D
